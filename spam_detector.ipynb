# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# Due to the large amount of data in the dataset, and potential complex interactions between the features to determine if an E-mail is spam.
# I predict Random Forests Classifier will preform better.

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`
y = data['spam']
X = data.drop('spam',axis=1)

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
y.value_counts()
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X,y)
X_train
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 3629            0.00               0.00           0.00           0.0
# 3658            0.00               0.00           0.00           0.0
# 3079            0.00              14.28           0.00           0.0
# 1850            0.00               0.00           1.58           0.0
# 1064            0.00               0.06           0.20           0.0
# ...              ...                ...            ...           ...
# 2380            0.00               0.00           2.25           0.0
# 2991            0.00               0.00           0.00           0.0
# 2229            0.39               0.00           0.00           0.0
# 1299            0.00               0.00           0.00           0.0
# 1188            0.00               0.53           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the training data
x_train_scaled = scaler.transform(X_train)
x_test_scaled = scaler.transform(X_test)
print(f' trained: {x_train_scaled} \n')
print(f'\n test:{x_test_scaled}')
# Out:
#  trained: [[-0.3459104  -0.16516577 -0.55510633 ... -0.14009353 -0.24574404
#   -0.45288299]
#  [-0.3459104  -0.16516577 -0.55510633 ... -0.14009353 -0.24574404
#   -0.45288299]
#  [-0.3459104  11.12375868 -0.55510633 ... -0.11269696 -0.22662463
#   -0.44640983]
#  ...
#  [ 0.93734099 -0.16516577 -0.55510633 ... -0.06636252  0.02192775
#   -0.06287544]
#  [-0.3459104  -0.16516577 -0.55510633 ... -0.11666947 -0.20272536
#   -0.4091892 ]
#  [-0.3459104   0.25382092 -0.55510633 ... -0.10136164 -0.19316565
#   -0.32989306]]
#
#
#  test:[[-0.3459104  -0.16516577 -0.55510633 ... -0.08115667 -0.06888946
#    0.45497691]
#  [-0.3459104  -0.16516577 -0.55510633 ... -0.14009353 -0.24574404
#   -0.45288299]
#  [-0.3459104  -0.16516577 -0.55510633 ... -0.13303892 -0.22662463
#   -0.34769423]
#  ...
#  [-0.3459104  -0.16516577 -0.55510633 ... -0.09636176 -0.19316565
#   -0.3946246 ]
#  [-0.3459104  -0.16516577 -0.55510633 ... -0.12053923 -0.22662463
#   -0.44317326]
# ...

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score
from sklearn.linear_model import LogisticRegression

logic_model = LogisticRegression(random_state=1)
logic_model.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
print(f'training:{logic_model.score(x_train_scaled,y_train)}')
# Out:
# training:0.9284057971014493

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
testing_predictions = logic_model.predict(x_test_scaled)

# Review the predictions
print(f'predictions: {testing_predictions} \n y_test: {y_test}')
# Out:
# predictions: [0 0 0 ... 0 0 0]
#  y_test: 1896    0
# 4062    0
# 4057    0
# 36      1
# 695     1
#        ..
# 3453    0
# 2731    0
# 3335    0
# 4580    0
# 3212    0
# Name: spam, Length: 1151, dtype: int64

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
print(f'logistic regression accuracy score:{accuracy_score(y_test,testing_predictions)}')
# Out:
# logistic regression accuracy score:0.9165942658557776

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier

random_model = RandomForestClassifier(random_state=1)
random_model
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
random_model = random_model.fit(x_train_scaled,y_train)
random_predictions = random_model.predict(x_test_scaled)
# Review the predictions
print(f'random_predictions:{random_predictions} \n training:{random_model.score(x_train_scaled,y_train)}')
# Out:
# random_predictions:[0 0 0 ... 0 0 0]
#  training:0.9994202898550725

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
print(f'random forest accuracy score:{accuracy_score(y_test,random_predictions)}')
# Out:
# random forest accuracy score:0.946133796698523

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# The Random Forest model preformed better (view accuracy score comparison below) as predicted.
# The ability to break down into true/false statements and check against other trees to determine
# if the E-mail was spam or not allows for better performance than the logistic regression model.

# %%
print(f' random forest accuracy score: {accuracy_score(y_test,random_predictions)}\n logistic regression accuracy score: {accuracy_score(y_test,testing_predictions)}')
# Out:
#  random forest accuracy score: 0.946133796698523
#  logistic regression accuracy score: 0.9165942658557776
